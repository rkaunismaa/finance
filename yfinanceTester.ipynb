# %% [markdown]
# Sunday, January 8, 2023
#
# First time playing with yfinance. I want to get an understanding on what it can do and show.
#
# https://pypi.org/project/yfinance/
#
# conda activate finance

# %% [markdown]
# Saturday, March 11, 2023
#
# Renewed exploration of the yfinance code base.
#
# The conda environment finance does NOT have yfinance installed.

# %%
# append the path to the yfinance module.
# 

import sys		
sys.path.append('/home/rob/Data/Documents/Github/ranaroussi/yfinance')

# %%
import yfinance as yf

# %% [markdown]
# ### The Ticker module

# %% [markdown]
# The Ticker module, which allows you to access ticker data in a more Pythonic way:

# %%
msft = None

# %%
# This does NOT make any api calls!
msft = yf.Ticker("MSFT")

# %%
# get stock info

# This makes these calls ...
# https://finance.yahoo.com/quote/MSFT
# https://query1.finance.yahoo.com/ws/fundamentals-timeseries/v1/finance/timeseries/MSFT?symbol=MSFT&type=trailingPegRatio&period1=1657553237&period2=1673368037

# Launch this again for the first time, it changes the values for period1 and period2 ...
# https://query1.finance.yahoo.com/ws/fundamentals-timeseries/v1/finance/timeseries/MSFT?symbol=MSFT&type=trailingPegRatio&period1=1657553514&period2=1673368314

# This now fails Saturday, March 11, 2023
# Exception: yfinance failed to decrypt Yahoo data response

# get all stock info (slow)
msft.info
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 14
#       1 # get stock info
#       2
#       3 # This makes these calls ...
#    (...)
#      12
#      13 # get all stock info (slow)
# ---> 14 msft.info
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:138, in Ticker.info(self)
#     136 @property
#     137 def info(self) -> dict:
# --> 138     return self.get_info()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/base.py:1477, in TickerBase.get_info(self, proxy)
#    1475 def get_info(self, proxy=None) -> dict:
#    1476     self._quote.proxy = proxy
# -> 1477     data = self._quote.info
#    1478     return data
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/quote.py:95, in Quote.info(self)
#      92 @property
#      93 def info(self) -> dict:
#      94     if self._info is None:
# ---> 95         self._scrape(self.proxy)
#      96         self._scrape_complementary(self.proxy)
#      98     return self._info
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/quote.py:124, in Quote._scrape(self, proxy)
#     121 self._already_scraped = True
#     123 # get info and sustainability
# --> 124 json_data = self._data.get_json_data_stores(proxy=proxy)
#     125 try:
#     126     quote_summary_store = json_data['QuoteSummaryStore']
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:41, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      39 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      40 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 41 return func(*args, **kwargs)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:311, in TickerData.get_json_data_stores(self, sub_page, proxy)
#     308     keys += response_gh.text.splitlines()
#     310 # Decrypt!
# --> 311 stores = decrypt_cryptojs_aes_stores(data, keys)
#     312 if stores is None:
#     313     # Maybe Yahoo returned old format, not encrypted
#     314     if "context" in data and "dispatcher" in data["context"]:
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:162, in decrypt_cryptojs_aes_stores(data, keys)
#     160             pass
#     161     if not success:
# --> 162         raise Exception("yfinance failed to decrypt Yahoo data response")
#     164 decoded_stores = json.loads(plaintext)
#     165 return decoded_stores
#
# Exception: yfinance failed to decrypt Yahoo data response

# %%
# fast access to subset of stock info (opportunistic)
msft.fast_info
# Out:
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']

# %%
# get historical market data
hist = msft.history(period="1mo")
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-02-13 00:00:00-05:00  266.971322  273.913924  266.482526  270.642120
# 2023-02-14 00:00:00-05:00  271.988772  274.283013  268.607227  271.490021
# 2023-02-15 00:00:00-05:00  268.320007  270.730011  266.179993  269.320007
# 2023-02-16 00:00:00-05:00  264.019989  266.739990  261.899994  262.149994
# 2023-02-17 00:00:00-05:00  259.390015  260.089996  256.000000  258.059998
# 2023-02-21 00:00:00-05:00  254.479996  255.490005  251.589996  252.669998
# 2023-02-22 00:00:00-05:00  254.089996  254.339996  250.339996  251.509995
# 2023-02-23 00:00:00-05:00  255.559998  256.839996  250.479996  254.770004
# 2023-02-24 00:00:00-05:00  249.960007  251.000000  248.100006  249.220001
# 2023-02-27 00:00:00-05:00  252.460007  252.820007  249.389999  250.160004
# 2023-02-28 00:00:00-05:00  249.070007  251.490005  248.729996  249.419998
# 2023-03-01 00:00:00-05:00  250.759995  250.929993  245.789993  246.270004
# 2023-03-02 00:00:00-05:00  246.550003  251.399994  245.610001  251.110001
# 2023-03-03 00:00:00-05:00  252.190002  255.619995  251.389999  255.289993
# 2023-03-06 00:00:00-05:00  256.429993  260.119995  255.979996  256.869995
# 2023-03-07 00:00:00-05:00  256.299988  257.690002  253.389999  254.149994
# 2023-03-08 00:00:00-05:00  254.039993  254.539993  250.809998  253.699997
# 2023-03-09 00:00:00-05:00  255.820007  259.559998  251.580002  252.320007
# 2023-03-10 00:00:00-05:00  251.080002  252.789993  247.600006  248.589996
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-02-13 00:00:00-05:00  44630900       0.00           0.0
# 2023-02-14 00:00:00-05:00  37047900       0.00           0.0
# 2023-02-15 00:00:00-05:00  28922400       0.68           0.0
# 2023-02-16 00:00:00-05:00  29603600       0.00           0.0
# 2023-02-17 00:00:00-05:00  30000100       0.00           0.0
# 2023-02-21 00:00:00-05:00  28397400       0.00           0.0
# 2023-02-22 00:00:00-05:00  22491100       0.00           0.0
# 2023-02-23 00:00:00-05:00  29219100       0.00           0.0
# 2023-02-24 00:00:00-05:00  24990900       0.00           0.0
# 2023-02-27 00:00:00-05:00  21190000       0.00           0.0
# 2023-02-28 00:00:00-05:00  22491000       0.00           0.0
# 2023-03-01 00:00:00-05:00  27565300       0.00           0.0
# 2023-03-02 00:00:00-05:00  24808200       0.00           0.0
# 2023-03-03 00:00:00-05:00  30741300       0.00           0.0
# 2023-03-06 00:00:00-05:00  24109800       0.00           0.0
# 2023-03-07 00:00:00-05:00  21473200       0.00           0.0
# 2023-03-08 00:00:00-05:00  17340200       0.00           0.0
# 2023-03-09 00:00:00-05:00  26653400       0.00           0.0
# 2023-03-10 00:00:00-05:00  28321800       0.00           0.0

# %%
# get historical market data

# This makes this call ...
# https://query2.finance.yahoo.com/v8/finance/chart/MSFT

hist = msft.history(period="max")
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.055241    0.063365    0.055241    0.060657
# 1986-03-14 00:00:00-05:00    0.060657    0.063907    0.060657    0.062823
# 1986-03-17 00:00:00-05:00    0.062823    0.064448    0.062823    0.063907
# 1986-03-18 00:00:00-05:00    0.063907    0.064448    0.061740    0.062281
# 1986-03-19 00:00:00-05:00    0.062281    0.062823    0.060657    0.061198
# ...                               ...         ...         ...         ...
# 2023-03-06 00:00:00-05:00  256.429993  260.119995  255.979996  256.869995
# 2023-03-07 00:00:00-05:00  256.299988  257.690002  253.389999  254.149994
# 2023-03-08 00:00:00-05:00  254.039993  254.539993  250.809998  253.699997
# 2023-03-09 00:00:00-05:00  255.820007  259.559998  251.580002  252.320007
# 2023-03-10 00:00:00-05:00  251.080002  252.789993  247.600006  248.589996
#
#                                Volume  Dividends  Stock Splits
# Date
# 1986-03-13 00:00:00-05:00  1031788800        0.0           0.0
# 1986-03-14 00:00:00-05:00   308160000        0.0           0.0
# 1986-03-17 00:00:00-05:00   133171200        0.0           0.0
# 1986-03-18 00:00:00-05:00    67766400        0.0           0.0
# 1986-03-19 00:00:00-05:00    47894400        0.0           0.0
# ...                               ...        ...           ...
# 2023-03-06 00:00:00-05:00    24109800        0.0           0.0
# 2023-03-07 00:00:00-05:00    21473200        0.0           0.0
# 2023-03-08 00:00:00-05:00    17340200        0.0           0.0
# 2023-03-09 00:00:00-05:00    26653400        0.0           0.0
# 2023-03-10 00:00:00-05:00    28321800        0.0           0.0
#
# [9324 rows x 7 columns]

# %%
# show meta information about the history (requires history() to be called first)
# This does not appear to get any new data but read from what has already been pulled.
msft.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': Timestamp('1986-03-13 09:30:00-0500', tz='America/New_York'),
#  'regularMarketTime': Timestamp('2023-03-10 16:00:05-0500', tz='America/New_York'),
#  'gmtoffset': -18000,
#  'timezone': 'EST',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 248.59,
#  'chartPreviousClose': 0.097,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'start': Timestamp('2023-03-10 04:00:00-0500', tz='America/New_York'),
#    'end': Timestamp('2023-03-10 09:30:00-0500', tz='America/New_York')},
#   'regular': {'start': Timestamp('2023-03-10 09:30:00-0500', tz='America/New_York'),
#    'end': Timestamp('2023-03-10 16:00:00-0500', tz='America/New_York')},
#   'post': {'start': Timestamp('2023-03-10 16:00:00-0500', tz='America/New_York'),
#    'end': Timestamp('2023-03-10 20:00:00-0500', tz='America/New_York')}},
#  'dataGranularity': '1d',
#  'range': '',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
# show actions (dividends, splits, capital gains)
# This does not appear to get any new data but read from what has already been pulled.
msft.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-09-21 00:00:00-04:00       0.00           2.0
# 1990-04-16 00:00:00-04:00       0.00           2.0
# 1991-06-27 00:00:00-04:00       0.00           1.5
# 1992-06-15 00:00:00-04:00       0.00           1.5
# 1994-05-23 00:00:00-04:00       0.00           2.0
# ...                              ...           ...
# 2022-02-16 00:00:00-05:00       0.62           0.0
# 2022-05-18 00:00:00-04:00       0.62           0.0
# 2022-08-17 00:00:00-04:00       0.62           0.0
# 2022-11-16 00:00:00-05:00       0.68           0.0
# 2023-02-15 00:00:00-05:00       0.68           0.0
#
# [86 rows x 2 columns]

# %%
# show dividends
# This does not appear to get any new data but read from what has already been pulled.
msft.dividends
# Out:
# Date
# 2003-02-19 00:00:00-05:00    0.08
# 2003-10-15 00:00:00-04:00    0.16
# 2004-08-23 00:00:00-04:00    0.08
# 2004-11-15 00:00:00-05:00    3.08
# 2005-02-15 00:00:00-05:00    0.08
#                              ...
# 2022-02-16 00:00:00-05:00    0.62
# 2022-05-18 00:00:00-04:00    0.62
# 2022-08-17 00:00:00-04:00    0.62
# 2022-11-16 00:00:00-05:00    0.68
# 2023-02-15 00:00:00-05:00    0.68
# Name: Dividends, Length: 77, dtype: float64

# %%
# show splits
# This does not appear to get any new data but read from what has already been pulled.
msft.splits
# Out:
# Date
# 1987-09-21 00:00:00-04:00    2.0
# 1990-04-16 00:00:00-04:00    2.0
# 1991-06-27 00:00:00-04:00    1.5
# 1992-06-15 00:00:00-04:00    1.5
# 1994-05-23 00:00:00-04:00    2.0
# 1996-12-09 00:00:00-05:00    2.0
# 1998-02-23 00:00:00-05:00    2.0
# 1999-03-29 00:00:00-05:00    2.0
# 2003-02-18 00:00:00-05:00    2.0
# Name: Stock Splits, dtype: float64

# %%
# show capital gains (for mutual funds & etfs)
# This does not appear to get any new data but read from what has already been pulled.
msft.capital_gains # only for mutual funds & etfs
# Out:
# []

# %%
# This now fails Saturday, March 11, 2023
# Exception: yfinance failed to decrypt Yahoo data response

# show share count
# - yearly summary:
msft.shares
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # show share count
#       2 # - yearly summary:
# ----> 3 msft.shares
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:134, in Ticker.shares(self)
#     132 @property
#     133 def shares(self) -> _pd.DataFrame :
# --> 134     return self.get_shares()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/base.py:1708, in TickerBase.get_shares(self, proxy, as_dict)
#    1706 def get_shares(self, proxy=None, as_dict=False):
#    1707     self._fundamentals.proxy = proxy
# -> 1708     data = self._fundamentals.shares
#    1709     if as_dict:
#    1710         return data.to_dict()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:40, in Fundamentals.shares(self)
#      37 @property
#      38 def shares(self) -> pd.DataFrame:
#      39     if self._shares is None:
# ---> 40         self._scrape_shares(self.proxy)
#      41     return self._shares
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:80, in Fundamentals._scrape_shares(self, proxy)
#      79 def _scrape_shares(self, proxy):
# ---> 80     self._scrape_basics(proxy)
#      81     # shares outstanding
#      82     try:
#      83         # keep only years with non None data
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:48, in Fundamentals._scrape_basics(self, proxy)
#      45     return
#      46 self._basics_already_scraped = True
# ---> 48 self._financials_data = self._data.get_json_data_stores('financials', proxy)
#      49 try:
#      50     self._fin_data_quote = self._financials_data['QuoteSummaryStore']
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:41, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      39 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      40 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 41 return func(*args, **kwargs)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:311, in TickerData.get_json_data_stores(self, sub_page, proxy)
#     308     keys += response_gh.text.splitlines()
#     310 # Decrypt!
# --> 311 stores = decrypt_cryptojs_aes_stores(data, keys)
#     312 if stores is None:
#     313     # Maybe Yahoo returned old format, not encrypted
#     314     if "context" in data and "dispatcher" in data["context"]:
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:162, in decrypt_cryptojs_aes_stores(data, keys)
#     160             pass
#     161     if not success:
# --> 162         raise Exception("yfinance failed to decrypt Yahoo data response")
#     164 decoded_stores = json.loads(plaintext)
#     165 return decoded_stores
#
# Exception: yfinance failed to decrypt Yahoo data response

# %%
# - accurate time-series count:
msft.get_shares_full(start="2022-01-01", end=None)
# Out:
# 2022-01-27 00:00:00-05:00    7496869888
# 2022-02-04 00:00:00-05:00    7800719872
# 2022-02-05 00:00:00-05:00    7496869888
# 2022-02-11 00:00:00-05:00    7496869888
# 2022-03-04 00:00:00-05:00    7605040128
# 2022-03-05 00:00:00-05:00    7496869888
# 2022-03-16 00:00:00-04:00    7595310080
# 2022-03-17 00:00:00-04:00    7496869888
# 2022-03-28 00:00:00-04:00    7507230208
# 2022-03-31 00:00:00-04:00    7496869888
# 2022-04-01 00:00:00-04:00    7631819776
# 2022-04-02 00:00:00-04:00    7496869888
# 2022-04-04 00:00:00-04:00    7496869888
# 2022-04-29 00:00:00-04:00    7479029760
# 2022-06-09 00:00:00-04:00    7536840192
# 2022-06-13 00:00:00-04:00    7479029760
# 2022-07-28 00:00:00-04:00    7464000000
# 2022-08-01 00:00:00-04:00    7457889792
# 2022-08-25 00:00:00-04:00    7475469824
# 2022-08-26 00:00:00-04:00    7457889792
# 2022-09-01 00:00:00-04:00    7457889792
# 2022-09-02 00:00:00-04:00    7488540160
# 2022-09-02 00:00:00-04:00    7457889792
# 2022-09-10 00:00:00-04:00    7290379776
# 2022-09-12 00:00:00-04:00    7457889792
# 2022-09-15 00:00:00-04:00    7451089920
# 2022-09-15 00:00:00-04:00    7457889792
# 2022-09-16 00:00:00-04:00    7665780224
# 2022-09-16 00:00:00-04:00    7457889792
# 2022-09-17 00:00:00-04:00    7457889792
# 2022-09-17 00:00:00-04:00    7477389824
# 2022-10-29 00:00:00-04:00    7454470144
# 2023-01-04 00:00:00-05:00    7461940224
# 2023-01-06 00:00:00-05:00    7454470144
# 2023-01-27 00:00:00-05:00    7443800064
# 2023-03-08 00:00:00-05:00    7523469824
# 2023-03-08 00:00:00-05:00    7443800064
# 2023-03-10 00:00:00-05:00    7443800064
# 2023-03-10 00:00:00-05:00    7484519936
# dtype: int64

# %%
# show financials:
# - income statement

# This now fails Saturday, March 11, 2023
# Exception: yfinance failed to decrypt Yahoo data response
msft.income_stmt
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 # show financials:
#       2 # - income statement
# ----> 3 msft.income_stmt
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:158, in Ticker.income_stmt(self)
#     156 @property
#     157 def income_stmt(self) -> _pd.DataFrame:
# --> 158     return self.get_income_stmt(pretty=True)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/base.py:1584, in TickerBase.get_income_stmt(self, proxy, as_dict, pretty, freq, legacy)
#    1582     data = self._fundamentals.financials.get_income_scrape(freq=freq, proxy=proxy)
#    1583 else:
# -> 1584     data = self._fundamentals.financials.get_income_time_series(freq=freq, proxy=proxy)
#    1586 if pretty:
#    1587     data = data.copy()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:113, in Financials.get_income_time_series(self, freq, proxy)
#     111 res = self._income_time_series
#     112 if freq not in res:
# --> 113     res[freq] = self._fetch_time_series("income", freq, proxy=None)
#     114 return res[freq]
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:142, in Financials._fetch_time_series(self, name, timescale, proxy)
#     139     raise ValueError("Illegal argument: timescale must be one of: {}".format(allowed_names))
#     141 try:
# --> 142     statement = self._create_financials_table(name, timescale, proxy)
#     144     if statement is not None:
#     145         return statement
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:155, in Financials._create_financials_table(self, name, timescale, proxy)
#     151 if name == "income":
#     152     # Yahoo stores the 'income' table internally under 'financials' key
#     153     name = "financials"
# --> 155 keys = self._get_datastore_keys(name, proxy)
#     156 try:
#     157     return self.get_financials_time_series(timescale, keys, proxy)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:162, in Financials._get_datastore_keys(self, sub_page, proxy)
#     161 def _get_datastore_keys(self, sub_page, proxy) -> list:
# --> 162     data_stores = self._data.get_json_data_stores(sub_page, proxy)
#     164     # Step 1: get the keys:
#     165     def _finditem1(key, obj):
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:41, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      39 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      40 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 41 return func(*args, **kwargs)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:311, in TickerData.get_json_data_stores(self, sub_page, proxy)
#     308     keys += response_gh.text.splitlines()
#     310 # Decrypt!
# --> 311 stores = decrypt_cryptojs_aes_stores(data, keys)
#     312 if stores is None:
#     313     # Maybe Yahoo returned old format, not encrypted
#     314     if "context" in data and "dispatcher" in data["context"]:
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:162, in decrypt_cryptojs_aes_stores(data, keys)
#     160             pass
#     161     if not success:
# --> 162         raise Exception("yfinance failed to decrypt Yahoo data response")
#     164 decoded_stores = json.loads(plaintext)
#     165 return decoded_stores
#
# Exception: yfinance failed to decrypt Yahoo data response

# %%
# This now fails Saturday, March 11, 2023
# Exception: yfinance failed to decrypt Yahoo data response
msft.quarterly_income_stmt
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 msft.quarterly_income_stmt
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:162, in Ticker.quarterly_income_stmt(self)
#     160 @property
#     161 def quarterly_income_stmt(self) -> _pd.DataFrame:
# --> 162     return self.get_income_stmt(pretty=True, freq='quarterly')
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/base.py:1584, in TickerBase.get_income_stmt(self, proxy, as_dict, pretty, freq, legacy)
#    1582     data = self._fundamentals.financials.get_income_scrape(freq=freq, proxy=proxy)
#    1583 else:
# -> 1584     data = self._fundamentals.financials.get_income_time_series(freq=freq, proxy=proxy)
#    1586 if pretty:
#    1587     data = data.copy()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:113, in Financials.get_income_time_series(self, freq, proxy)
#     111 res = self._income_time_series
#     112 if freq not in res:
# --> 113     res[freq] = self._fetch_time_series("income", freq, proxy=None)
#     114 return res[freq]
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:142, in Financials._fetch_time_series(self, name, timescale, proxy)
#     139     raise ValueError("Illegal argument: timescale must be one of: {}".format(allowed_names))
#     141 try:
# --> 142     statement = self._create_financials_table(name, timescale, proxy)
#     144     if statement is not None:
#     145         return statement
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:155, in Financials._create_financials_table(self, name, timescale, proxy)
#     151 if name == "income":
#     152     # Yahoo stores the 'income' table internally under 'financials' key
#     153     name = "financials"
# --> 155 keys = self._get_datastore_keys(name, proxy)
#     156 try:
#     157     return self.get_financials_time_series(timescale, keys, proxy)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:162, in Financials._get_datastore_keys(self, sub_page, proxy)
#     161 def _get_datastore_keys(self, sub_page, proxy) -> list:
# --> 162     data_stores = self._data.get_json_data_stores(sub_page, proxy)
#     164     # Step 1: get the keys:
#     165     def _finditem1(key, obj):
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:41, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      39 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      40 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 41 return func(*args, **kwargs)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:311, in TickerData.get_json_data_stores(self, sub_page, proxy)
#     308     keys += response_gh.text.splitlines()
#     310 # Decrypt!
# --> 311 stores = decrypt_cryptojs_aes_stores(data, keys)
#     312 if stores is None:
#     313     # Maybe Yahoo returned old format, not encrypted
#     314     if "context" in data and "dispatcher" in data["context"]:
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:162, in decrypt_cryptojs_aes_stores(data, keys)
#     160             pass
#     161     if not success:
# --> 162         raise Exception("yfinance failed to decrypt Yahoo data response")
#     164 decoded_stores = json.loads(plaintext)
#     165 return decoded_stores
#
# Exception: yfinance failed to decrypt Yahoo data response

# %%
# This now fails Saturday, March 11, 2023
# Exception: yfinance failed to decrypt Yahoo data response

# - balance sheet
msft.balance_sheet
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # - balance sheet
# ----> 2 msft.balance_sheet
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:182, in Ticker.balance_sheet(self)
#     180 @property
#     181 def balance_sheet(self) -> _pd.DataFrame:
# --> 182     return self.get_balance_sheet(pretty=True)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/base.py:1623, in TickerBase.get_balance_sheet(self, proxy, as_dict, pretty, freq, legacy)
#    1621     data = self._fundamentals.financials.get_balance_sheet_scrape(freq=freq, proxy=proxy)
#    1622 else:
# -> 1623     data = self._fundamentals.financials.get_balance_sheet_time_series(freq=freq, proxy=proxy)
#    1625 if pretty:
#    1626     data = data.copy()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:119, in Financials.get_balance_sheet_time_series(self, freq, proxy)
#     117 res = self._balance_sheet_time_series
#     118 if freq not in res:
# --> 119     res[freq] = self._fetch_time_series("balance-sheet", freq, proxy=None)
#     120 return res[freq]
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:142, in Financials._fetch_time_series(self, name, timescale, proxy)
#     139     raise ValueError("Illegal argument: timescale must be one of: {}".format(allowed_names))
#     141 try:
# --> 142     statement = self._create_financials_table(name, timescale, proxy)
#     144     if statement is not None:
#     145         return statement
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:155, in Financials._create_financials_table(self, name, timescale, proxy)
#     151 if name == "income":
#     152     # Yahoo stores the 'income' table internally under 'financials' key
#     153     name = "financials"
# --> 155 keys = self._get_datastore_keys(name, proxy)
#     156 try:
#     157     return self.get_financials_time_series(timescale, keys, proxy)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:162, in Financials._get_datastore_keys(self, sub_page, proxy)
#     161 def _get_datastore_keys(self, sub_page, proxy) -> list:
# --> 162     data_stores = self._data.get_json_data_stores(sub_page, proxy)
#     164     # Step 1: get the keys:
#     165     def _finditem1(key, obj):
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:41, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      39 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      40 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 41 return func(*args, **kwargs)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:311, in TickerData.get_json_data_stores(self, sub_page, proxy)
#     308     keys += response_gh.text.splitlines()
#     310 # Decrypt!
# --> 311 stores = decrypt_cryptojs_aes_stores(data, keys)
#     312 if stores is None:
#     313     # Maybe Yahoo returned old format, not encrypted
#     314     if "context" in data and "dispatcher" in data["context"]:
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:162, in decrypt_cryptojs_aes_stores(data, keys)
#     160             pass
#     161     if not success:
# --> 162         raise Exception("yfinance failed to decrypt Yahoo data response")
#     164 decoded_stores = json.loads(plaintext)
#     165 return decoded_stores
#
# Exception: yfinance failed to decrypt Yahoo data response

# %%
# This now fails Saturday, March 11, 2023
# Exception: yfinance failed to decrypt Yahoo data response
msft.quarterly_balance_sheet
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 msft.quarterly_balance_sheet
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:186, in Ticker.quarterly_balance_sheet(self)
#     184 @property
#     185 def quarterly_balance_sheet(self) -> _pd.DataFrame:
# --> 186     return self.get_balance_sheet(pretty=True, freq='quarterly')
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/base.py:1623, in TickerBase.get_balance_sheet(self, proxy, as_dict, pretty, freq, legacy)
#    1621     data = self._fundamentals.financials.get_balance_sheet_scrape(freq=freq, proxy=proxy)
#    1622 else:
# -> 1623     data = self._fundamentals.financials.get_balance_sheet_time_series(freq=freq, proxy=proxy)
#    1625 if pretty:
#    1626     data = data.copy()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:119, in Financials.get_balance_sheet_time_series(self, freq, proxy)
#     117 res = self._balance_sheet_time_series
#     118 if freq not in res:
# --> 119     res[freq] = self._fetch_time_series("balance-sheet", freq, proxy=None)
#     120 return res[freq]
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:142, in Financials._fetch_time_series(self, name, timescale, proxy)
#     139     raise ValueError("Illegal argument: timescale must be one of: {}".format(allowed_names))
#     141 try:
# --> 142     statement = self._create_financials_table(name, timescale, proxy)
#     144     if statement is not None:
#     145         return statement
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:155, in Financials._create_financials_table(self, name, timescale, proxy)
#     151 if name == "income":
#     152     # Yahoo stores the 'income' table internally under 'financials' key
#     153     name = "financials"
# --> 155 keys = self._get_datastore_keys(name, proxy)
#     156 try:
#     157     return self.get_financials_time_series(timescale, keys, proxy)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:162, in Financials._get_datastore_keys(self, sub_page, proxy)
#     161 def _get_datastore_keys(self, sub_page, proxy) -> list:
# --> 162     data_stores = self._data.get_json_data_stores(sub_page, proxy)
#     164     # Step 1: get the keys:
#     165     def _finditem1(key, obj):
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:41, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      39 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      40 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 41 return func(*args, **kwargs)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:311, in TickerData.get_json_data_stores(self, sub_page, proxy)
#     308     keys += response_gh.text.splitlines()
#     310 # Decrypt!
# --> 311 stores = decrypt_cryptojs_aes_stores(data, keys)
#     312 if stores is None:
#     313     # Maybe Yahoo returned old format, not encrypted
#     314     if "context" in data and "dispatcher" in data["context"]:
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:162, in decrypt_cryptojs_aes_stores(data, keys)
#     160             pass
#     161     if not success:
# --> 162         raise Exception("yfinance failed to decrypt Yahoo data response")
#     164 decoded_stores = json.loads(plaintext)
#     165 return decoded_stores
#
# Exception: yfinance failed to decrypt Yahoo data response

# %%
# This now fails Saturday, March 11, 2023
# Exception: yfinance failed to decrypt Yahoo data response

# - cash flow statement
msft.cashflow
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # - cash flow statement
# ----> 2 msft.cashflow
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:206, in Ticker.cashflow(self)
#     204 @property
#     205 def cashflow(self) -> _pd.DataFrame:
# --> 206     return self.cash_flow
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:198, in Ticker.cash_flow(self)
#     196 @property
#     197 def cash_flow(self) -> _pd.DataFrame:
# --> 198     return self.get_cash_flow(pretty=True, freq="yearly")
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/base.py:1659, in TickerBase.get_cash_flow(self, proxy, as_dict, pretty, freq, legacy)
#    1657     data = self._fundamentals.financials.get_cash_flow_scrape(freq=freq, proxy=proxy)
#    1658 else:
# -> 1659     data = self._fundamentals.financials.get_cash_flow_time_series(freq=freq, proxy=proxy)
#    1661 if pretty:
#    1662     data = data.copy()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:125, in Financials.get_cash_flow_time_series(self, freq, proxy)
#     123 res = self._cash_flow_time_series
#     124 if freq not in res:
# --> 125     res[freq] = self._fetch_time_series("cash-flow", freq, proxy=None)
#     126 return res[freq]
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:142, in Financials._fetch_time_series(self, name, timescale, proxy)
#     139     raise ValueError("Illegal argument: timescale must be one of: {}".format(allowed_names))
#     141 try:
# --> 142     statement = self._create_financials_table(name, timescale, proxy)
#     144     if statement is not None:
#     145         return statement
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:155, in Financials._create_financials_table(self, name, timescale, proxy)
#     151 if name == "income":
#     152     # Yahoo stores the 'income' table internally under 'financials' key
#     153     name = "financials"
# --> 155 keys = self._get_datastore_keys(name, proxy)
#     156 try:
#     157     return self.get_financials_time_series(timescale, keys, proxy)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:162, in Financials._get_datastore_keys(self, sub_page, proxy)
#     161 def _get_datastore_keys(self, sub_page, proxy) -> list:
# --> 162     data_stores = self._data.get_json_data_stores(sub_page, proxy)
#     164     # Step 1: get the keys:
#     165     def _finditem1(key, obj):
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:41, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      39 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      40 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 41 return func(*args, **kwargs)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:311, in TickerData.get_json_data_stores(self, sub_page, proxy)
#     308     keys += response_gh.text.splitlines()
#     310 # Decrypt!
# --> 311 stores = decrypt_cryptojs_aes_stores(data, keys)
#     312 if stores is None:
#     313     # Maybe Yahoo returned old format, not encrypted
#     314     if "context" in data and "dispatcher" in data["context"]:
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:162, in decrypt_cryptojs_aes_stores(data, keys)
#     160             pass
#     161     if not success:
# --> 162         raise Exception("yfinance failed to decrypt Yahoo data response")
#     164 decoded_stores = json.loads(plaintext)
#     165 return decoded_stores
#
# Exception: yfinance failed to decrypt Yahoo data response

# %%
# This now fails Saturday, March 11, 2023
# Exception: yfinance failed to decrypt Yahoo data response

msft.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 msft.quarterly_cashflow
#       2 # see `Ticker.get_income_stmt()` for more options
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:210, in Ticker.quarterly_cashflow(self)
#     208 @property
#     209 def quarterly_cashflow(self) -> _pd.DataFrame:
# --> 210     return self.quarterly_cash_flow
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:202, in Ticker.quarterly_cash_flow(self)
#     200 @property
#     201 def quarterly_cash_flow(self) -> _pd.DataFrame:
# --> 202     return self.get_cash_flow(pretty=True, freq='quarterly')
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/base.py:1659, in TickerBase.get_cash_flow(self, proxy, as_dict, pretty, freq, legacy)
#    1657     data = self._fundamentals.financials.get_cash_flow_scrape(freq=freq, proxy=proxy)
#    1658 else:
# -> 1659     data = self._fundamentals.financials.get_cash_flow_time_series(freq=freq, proxy=proxy)
#    1661 if pretty:
#    1662     data = data.copy()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:125, in Financials.get_cash_flow_time_series(self, freq, proxy)
#     123 res = self._cash_flow_time_series
#     124 if freq not in res:
# --> 125     res[freq] = self._fetch_time_series("cash-flow", freq, proxy=None)
#     126 return res[freq]
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:142, in Financials._fetch_time_series(self, name, timescale, proxy)
#     139     raise ValueError("Illegal argument: timescale must be one of: {}".format(allowed_names))
#     141 try:
# --> 142     statement = self._create_financials_table(name, timescale, proxy)
#     144     if statement is not None:
#     145         return statement
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:155, in Financials._create_financials_table(self, name, timescale, proxy)
#     151 if name == "income":
#     152     # Yahoo stores the 'income' table internally under 'financials' key
#     153     name = "financials"
# --> 155 keys = self._get_datastore_keys(name, proxy)
#     156 try:
#     157     return self.get_financials_time_series(timescale, keys, proxy)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/fundamentals.py:162, in Financials._get_datastore_keys(self, sub_page, proxy)
#     161 def _get_datastore_keys(self, sub_page, proxy) -> list:
# --> 162     data_stores = self._data.get_json_data_stores(sub_page, proxy)
#     164     # Step 1: get the keys:
#     165     def _finditem1(key, obj):
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:41, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      39 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      40 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 41 return func(*args, **kwargs)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:311, in TickerData.get_json_data_stores(self, sub_page, proxy)
#     308     keys += response_gh.text.splitlines()
#     310 # Decrypt!
# --> 311 stores = decrypt_cryptojs_aes_stores(data, keys)
#     312 if stores is None:
#     313     # Maybe Yahoo returned old format, not encrypted
#     314     if "context" in data and "dispatcher" in data["context"]:
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:162, in decrypt_cryptojs_aes_stores(data, keys)
#     160             pass
#     161     if not success:
# --> 162         raise Exception("yfinance failed to decrypt Yahoo data response")
#     164 decoded_stores = json.loads(plaintext)
#     165 return decoded_stores
#
# Exception: yfinance failed to decrypt Yahoo data response

# %%
# show major holders
msft.major_holders
# Out:
#         0                                      1
# 0   0.06%        % of Shares Held by All Insider
# 1  73.70%       % of Shares Held by Institutions
# 2  73.75%        % of Float Held by Institutions
# 3    6152  Number of Institutions Holding Shares

# %%
# show institutional holders
msft.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  642664898    2022-12-30  0.0863
# 1                     Blackrock Inc.  532042708    2022-12-30  0.0715
# 2           State Street Corporation  294574683    2022-12-30  0.0396
# 3                           FMR, LLC  198985661    2022-12-30  0.0267
# 4      Price (T.Rowe) Associates Inc  168647376    2022-12-30  0.0227
# 5      Geode Capital Management, LLC  142731177    2022-12-30  0.0192
# 6                     Morgan Stanley  119417954    2022-12-30  0.0160
# 7          JP Morgan Chase & Company   93021058    2022-12-30  0.0125
# 8            Capital World Investors   91715063    2022-12-30  0.0123
# 9  Norges Bank Investment Management   86316926    2022-12-30  0.0116
#
#           Value
# 0  159760064640
# 1  132260494833
# 2   73228319368
# 3   49465844739
# 4   41924050582
# 5   35481542767
# 6   29686108747
# 7   23124104467
# 8   22799447175
# 9   21457524318

# %%
# show mutualfund holders
msft.mutualfund_holders
# Out:
#                                               Holder     Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  222313847    2022-09-29
# 1                            Vanguard 500 Index Fund  169062762    2022-09-29
# 2                             SPDR S&P 500 ETF Trust   82250000    2022-12-30
# 3                            Fidelity 500 Index Fund   81679555    2022-12-30
# 4        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   76335623    2022-12-30
# 5                           iShares Core S&P 500 ETF   66940817    2022-12-30
# 6                         Vanguard Growth Index Fund   61426549    2022-09-29
# 7  Vanguard Institutional Index Fund-Institutiona...   54149972    2022-09-29
# 8                         Growth Fund Of America Inc   44491127    2022-12-30
# 9                 Select Sector SPDR Fund-Technology   34910084    2022-12-30
#
#     % Out        Value
# 0  0.0299  55264998411
# 1  0.0227  42027311386
# 2  0.0110  20446527198
# 3  0.0110  20304720278
# 4  0.0103  18976272242
# 5  0.0090  16640817452
# 6  0.0083  15270025590
# 7  0.0073  13461141341
# 8  0.0060  11060049097
# 9  0.0047   8678297653

# %%
# show earnings
msft.earnings
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
msft.quarterly_earnings
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# show sustainability
msft.sustainability

# %%
# show analysts recommendations
msft.recommendations

# %%
msft.recommendations_summary

# %%
# This now fails Saturday, March 11, 2023
# Exception: yfinance failed to decrypt Yahoo data response

# show analysts other work
msft.analyst_price_target
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 # show analysts other work
# ----> 2 msft.analyst_price_target
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:218, in Ticker.analyst_price_target(self)
#     216 @property
#     217 def analyst_price_target(self) -> _pd.DataFrame:
# --> 218     return self.get_analyst_price_target()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/base.py:1505, in TickerBase.get_analyst_price_target(self, proxy, as_dict)
#    1503 def get_analyst_price_target(self, proxy=None, as_dict=False):
#    1504     self._analysis.proxy = proxy
# -> 1505     data = self._analysis.analyst_price_target
#    1506     if as_dict:
#    1507         return data.to_dict()
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/analysis.py:35, in Analysis.analyst_price_target(self)
#      32 @property
#      33 def analyst_price_target(self) -> pd.DataFrame:
#      34     if self._analyst_price_target is None:
# ---> 35         self._scrape(self.proxy)
#      36     return self._analyst_price_target
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/scrapers/analysis.py:56, in Analysis._scrape(self, proxy)
#      53 self._already_scraped = True
#      55 # Analysis Data/Analyst Forecasts
# ---> 56 analysis_data = self._data.get_json_data_stores("analysis", proxy=proxy)
#      57 try:
#      58     analysis_data = analysis_data['QuoteSummaryStore']
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:41, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      39 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      40 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 41 return func(*args, **kwargs)
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:311, in TickerData.get_json_data_stores(self, sub_page, proxy)
#     308     keys += response_gh.text.splitlines()
#     310 # Decrypt!
# --> 311 stores = decrypt_cryptojs_aes_stores(data, keys)
#     312 if stores is None:
#     313     # Maybe Yahoo returned old format, not encrypted
#     314     if "context" in data and "dispatcher" in data["context"]:
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/data.py:162, in decrypt_cryptojs_aes_stores(data, keys)
#     160             pass
#     161     if not success:
# --> 162         raise Exception("yfinance failed to decrypt Yahoo data response")
#     164 decoded_stores = json.loads(plaintext)
#     165 return decoded_stores
#
# Exception: yfinance failed to decrypt Yahoo data response

# %%
msft.revenue_forecasts

# %%
msft.earnings_forecasts

# %%
msft.earnings_trend

# %%
# show next event (earnings, etc)
msft.calendar

# %%
# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2024-01-22 16:00:00-05:00           NaN           NaN          NaN
# 2024-01-22 05:00:00-05:00           NaN           NaN          NaN
# 2023-10-23 06:00:00-04:00           NaN           NaN          NaN
# 2023-07-24 06:00:00-04:00           NaN           NaN          NaN
# 2023-04-24 06:00:00-04:00          2.23           NaN          NaN
# 2023-01-24 11:00:00-05:00          2.30          2.32       0.0109
# 2022-10-25 12:00:00-04:00          2.30          2.35       0.0204
# 2022-07-26 12:00:00-04:00          2.29          2.23      -0.0275
# 2022-04-26 12:00:00-04:00          2.19          2.22       0.0160
# 2022-01-25 11:00:00-05:00          2.31          2.48       0.0727
# 2021-10-26 12:00:00-04:00          2.08          2.27       0.0940
# 2021-07-27 12:00:00-04:00          1.92          2.17       0.1326

# %%
# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# %%
# show options expirations
msft.options
# Out:
# ('2023-03-17',
#  '2023-03-24',
#  '2023-03-31',
#  '2023-04-06',
#  '2023-04-14',
#  '2023-04-21',
#  '2023-05-19',
#  '2023-06-16',
#  '2023-07-21',
#  '2023-08-18',
#  '2023-09-15',
#  '2023-10-20',
#  '2024-01-19',
#  '2024-06-21',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-06-20',
#  '2025-12-19')

# %%
# show news
msft.news
# Out:
# [{'uuid': 'c00cd7f1-b74f-396e-b43e-02d000628af4',
#   'title': "Microsoft's AI Ambitions Go Way Beyond Bing",
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/c00cd7f1-b74f-396e-b43e-02d000628af4/microsoft%27s-ai-ambitions-go.html',
#   'providerPublishTime': 1678538330,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/cDA7J.1wOxoV0PxH2oMOQQ--~B/aD03MjA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/a2a334bfeec318c854ac7a57a133be54',
#      'width': 1280,
#      'height': 720,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/SPTDH_E0L1oG391Y3fqjzA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/a2a334bfeec318c854ac7a57a133be54',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': 'd63210ba-77d7-376f-bef6-6229588e1dab',
#   'title': 'Weekly Roundup',
#   'publisher': 'TheStreet.com',
#   'link': 'https://finance.yahoo.com/m/d63210ba-77d7-376f-bef6-6229588e1dab/weekly-roundup.html',
#   'providerPublishTime': 1678492200,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ewQjnXQ8otU7OLaOOrC91Q--~B/aD04MDA7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/thestreet.com/2c7a8587db6dfb0418a7ae3bd621e1c3',
#      'width': 1200,
#      'height': 800,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/GkCJ6HDnZ1PsXGaoVzJA3w--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/thestreet.com/2c7a8587db6dfb0418a7ae3bd621e1c3',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['VZ',
#    'SIVB',
#    '^GSPC',
#    'MA',
#    'LMT',
#    '^RUT',
#    'AAPL',
#    'MSFT',
#    'GOOGL',
#    'ELV',
#    'MRVL',
#    'PEP',
#    'CHPT']},
#  {'uuid': 'b390fde6-9c73-3c05-ad47-aea6671177b3',
#   'title': '2 Hypergrowth Stocks to Buy in 2023 and Beyond',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/b390fde6-9c73-3c05-ad47-aea6671177b3/2-hypergrowth-stocks-to-buy.html',
#   'providerPublishTime': 1678485600,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/.J7SvQ1VfP9D9l8gVSyBhg--~B/aD0xNDE0O3c9MjEyMTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/a77a5f91420812f17b88b16ecc785818',
#      'width': 2121,
#      'height': 1414,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/TEK5Hc9ic1id1_zdkgIV.Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/a77a5f91420812f17b88b16ecc785818',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['AMD', 'MSFT']},
#  {'uuid': 'a9d973c3-d6bd-3d0a-9231-00470a975777',
#   'title': 'UPDATE 1-GM explores using ChatGPT in vehicles',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/1-gm-explores-using-chatgpt-193159776.html',
#   'providerPublishTime': 1678476719,
#   'type': 'STORY',
#   'relatedTickers': ['GM', 'MSFT']},
#  {'uuid': 'af9c47e0-2c4d-39f1-a06f-16a030f03512',
#   'title': 'Tech, Finance Companies Continue to Cut Jobs Despite Strong Broader Labor Market',
#   'publisher': 'The Wall Street Journal',
#   'link': 'https://finance.yahoo.com/m/af9c47e0-2c4d-39f1-a06f-16a030f03512/tech%2C-finance-companies.html',
#   'providerPublishTime': 1678474980,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/kZPvS1fnlKHcoa1KE8MVdA--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/018f882b770920533c0a3dece0da8401',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/W2RSckk2.cDT_JwCYTIvYg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/018f882b770920533c0a3dece0da8401',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': 'a299b9fd-605f-3bee-88c3-4805581e270d',
#   'title': 'GM explores using ChatGPT in vehicles',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/gm-explores-using-chatgpt-vehicles-184256154.html',
#   'providerPublishTime': 1678473776,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ruR_WvwGabN_XsQjiYGHCA--~B/aD01MDQ7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/4566e1144a66c7fef39fb6daad581fb8',
#      'width': 800,
#      'height': 504,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/eu4qk9AGZ6zS4eqoZH8IIA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/reuters-finance.com/4566e1144a66c7fef39fb6daad581fb8',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GM', 'MSFT']},
#  {'uuid': 'f0ccdb51-d367-3a10-b011-8cb755765afc',
#   'title': 'CORRECTED-GM explores using ChatGPT in vehicles',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/gm-explores-using-chatgpt-vehicles-183518269.html',
#   'providerPublishTime': 1678473318,
#   'type': 'STORY',
#   'relatedTickers': ['GM', 'MSFT']},
#  {'uuid': '453368b8-050f-3394-a629-502d72ece83d',
#   'title': 'Microsoft Federal’s Rick Wagner discusses the competition with other industry giants — and what he sees for 2023',
#   'publisher': 'American City Business Journals',
#   'link': 'https://finance.yahoo.com/m/453368b8-050f-3394-a629-502d72ece83d/microsoft-federal%E2%80%99s-rick.html',
#   'providerPublishTime': 1678473010,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/OAOWlVwkGQwJN1jtcyi90A--~B/aD0yMTYwO3c9MTQ0MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/bizjournals.com/602b4f22a5adaf1703b55a59df84fa7f',
#      'width': 1440,
#      'height': 2160,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/WGYyl4hEbYNZB6xLZ63Gkw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bizjournals.com/602b4f22a5adaf1703b55a59df84fa7f',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']}]

# %%
# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 # get option chain for specific expiration
# ----> 2 opt = msft.option_chain('YYYY-MM-DD')
#       3 # data available via: opt.calls, opt.puts
#
# File ~/Data/Documents/Github/ranaroussi/yfinance/yfinance/ticker.py:86, in Ticker.option_chain(self, date, proxy, tz)
#      84     self._download_options()
#      85 if date not in self._expirations:
# ---> 86     raise ValueError(
#      87         "Expiration `%s` cannot be found. "
#      88         "Available expiration are: [%s]" % (
#      89             date, ', '.join(self._expirations)))
#      90 date = self._expirations[date]
#      91 options = self._download_options(date, proxy=proxy)
#
# ValueError: Expiration `YYYY-MM-DD` cannot be found. Available expiration are: [2023-03-17, 2023-03-24, 2023-03-31, 2023-04-06, 2023-04-14, 2023-04-21, 2023-05-19, 2023-06-16, 2023-07-21, 2023-08-18, 2023-09-15, 2023-10-20, 2024-01-19, 2024-06-21, 2024-12-20, 2025-01-17, 2025-06-20, 2025-12-19]

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "SPY AAPL MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "ytd",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "5d",

        # Whether to ignore timezone when aligning ticker data from 
        # different timezones. Default is True. False may be useful for 
        # minute/hourly data.
        ignore_tz = False,

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # attempt repair of missing data or currency mixups e.g. $/cents
        repair = False,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
